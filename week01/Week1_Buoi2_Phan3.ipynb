# %% [markdown]
# <a href="https://colab.research.google.com/github/tutrong207/mliot-pyml-2026-hw/blob/main/week02/Week1_Buoi2_Phan3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

df = sns.load_dataset("iris")

print(df.head())
print(df.shape)
print(df.dtypes)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# (150, 5)
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
print(df.shape)
cov_matrix = df.drop(columns=['species']).cov()
print("Ma trận hiệp phương sai:", cov_matrix)
print(cov_matrix.shape)

corr_matrix = df.drop(columns=['species']).corr()
print("Ma trận tương quan:", corr_matrix)
print(corr_matrix.shape)
# Out:
# (150, 5)
# Ma trận hiệp phương sai:               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      0.685694    -0.042434      1.274315     0.516271
# sepal_width      -0.042434     0.189979     -0.329656    -0.121639
# petal_length      1.274315    -0.329656      3.116278     1.295609
# petal_width       0.516271    -0.121639      1.295609     0.581006
# (4, 4)
# Ma trận tương quan:               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000
# (4, 4)

# %%
sns.heatmap(data=corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.pairplot(data=df, hue='species')
